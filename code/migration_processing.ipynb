# %%
import pandas as pd

# %%
df = pd.read_csv("ukr_migration (1).csv")
df
# Out:
#                                          Indicator                     Region  \
# 0                      Migration population growth                    Ukraine
# 1                      Migration population growth  Avtonomna Respublika Krym
# 2                      Migration population growth                  Vinnytska
# 3                      Migration population growth                   Volynska
# 4                      Migration population growth            Dnipropetrovska
# ..                                             ...                        ...
# 79  Migration growth (reduction) of the population                  Cherkaska
# 80  Migration growth (reduction) of the population               Chernivetska
# 81  Migration growth (reduction) of the population               Chernihivska
# 82  Migration growth (reduction) of the population                       Kyiv
# 83  Migration growth (reduction) of the population                 Sevastopol
#
# ...

# %%
filtered_df = df[df['Indicator'] == 'Migration population reduction']
filtered_df.dropna(inplace=True)
filtered_df
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_27940\1511415571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.dropna(inplace=True)
#                          Indicator            Region Frequency  2021-M01  \
# 28  Migration population reduction           Ukraine   Monthly   23694.0
# 30  Migration population reduction         Vinnytska   Monthly     975.0
# 31  Migration population reduction          Volynska   Monthly     650.0
# 32  Migration population reduction   Dnipropetrovska   Monthly    1378.0
# 33  Migration population reduction          Donetska   Monthly     958.0
# 34  Migration population reduction       Zhytomyrska   Monthly     929.0
# 35  Migration population reduction       Zakarpatska   Monthly     327.0
# ...

# %%
average_values = filtered_df.iloc[:, 3:].mean(axis=1)
filtered_df["mean"] = average_values
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_27940\2064914943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["mean"] = average_values

# %%
filtered_df
# Out:
#                          Indicator            Region Frequency  2021-M01  \
# 28  Migration population reduction           Ukraine   Monthly   23694.0
# 30  Migration population reduction         Vinnytska   Monthly     975.0
# 31  Migration population reduction          Volynska   Monthly     650.0
# 32  Migration population reduction   Dnipropetrovska   Monthly    1378.0
# 33  Migration population reduction          Donetska   Monthly     958.0
# 34  Migration population reduction       Zhytomyrska   Monthly     929.0
# 35  Migration population reduction       Zakarpatska   Monthly     327.0
# 36  Migration population reduction         Zaporizka   Monthly     763.0
# 37  Migration population reduction  Ivano-Frankivska   Monthly     647.0
# 38  Migration population reduction           Kyivska   Monthly    1269.0
# 39  Migration population reduction     Kirovohradska   Monthly     628.0
# 40  Migration population reduction          Luhanska   Monthly     458.0
# ...

# %%
df2 = pd.DataFrame()
df2["region"] = filtered_df["Region"]
df2["migration_reduction"] = filtered_df["mean"]
df2.to_csv("ukr_migration_out.csv")
