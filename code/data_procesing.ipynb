# %%
import pandas as pd

# %%
df = pd.read_csv("migration_ukraine.csv")
df
# Out:
#                       Indicator                     Region Frequency  \
# 0   Migration population growth                    Ukraine   Monthly
# 1   Migration population growth  Avtonomna Respublika Krym   Monthly
# 2   Migration population growth                  Vinnytska   Monthly
# 3   Migration population growth                   Volynska   Monthly
# 4   Migration population growth            Dnipropetrovska   Monthly
# 5   Migration population growth                   Donetska   Monthly
# 6   Migration population growth                Zhytomyrska   Monthly
# 7   Migration population growth                Zakarpatska   Monthly
# 8   Migration population growth                  Zaporizka   Monthly
# 9   Migration population growth           Ivano-Frankivska   Monthly
# 10  Migration population growth                    Kyivska   Monthly
# 11  Migration population growth              Kirovohradska   Monthly
# 12  Migration population growth                   Luhanska   Monthly
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                       Indicator            Region Frequency  2021-M01  \
# 0   Migration population growth           Ukraine   Monthly   25966.0
# 2   Migration population growth         Vinnytska   Monthly     986.0
# 3   Migration population growth          Volynska   Monthly     673.0
# 4   Migration population growth   Dnipropetrovska   Monthly    1624.0
# 5   Migration population growth          Donetska   Monthly     894.0
# 6   Migration population growth       Zhytomyrska   Monthly     913.0
# 7   Migration population growth       Zakarpatska   Monthly     384.0
# 8   Migration population growth         Zaporizka   Monthly     738.0
# 9   Migration population growth  Ivano-Frankivska   Monthly     720.0
# 10  Migration population growth           Kyivska   Monthly    2972.0
# 11  Migration population growth     Kirovohradska   Monthly     555.0
# 12  Migration population growth          Luhanska   Monthly     314.0
# ...

# %%
average_values = df.iloc[:, 3:].mean(axis=1)

# %%
df["mean"] = average_values

# %%
df
# Out:
#                       Indicator            Region Frequency  2021-M01  \
# 0   Migration population growth           Ukraine   Monthly   25966.0
# 2   Migration population growth         Vinnytska   Monthly     986.0
# 3   Migration population growth          Volynska   Monthly     673.0
# 4   Migration population growth   Dnipropetrovska   Monthly    1624.0
# 5   Migration population growth          Donetska   Monthly     894.0
# 6   Migration population growth       Zhytomyrska   Monthly     913.0
# 7   Migration population growth       Zakarpatska   Monthly     384.0
# 8   Migration population growth         Zaporizka   Monthly     738.0
# 9   Migration population growth  Ivano-Frankivska   Monthly     720.0
# 10  Migration population growth           Kyivska   Monthly    2972.0
# 11  Migration population growth     Kirovohradska   Monthly     555.0
# 12  Migration population growth          Luhanska   Monthly     314.0
# ...

# %%
df2 = pd.DataFrame()
df2["region"] = df["Region"]
df2["migration_growth"] = df["mean"]
df2.to_csv("ukr_migration_in.csv")
